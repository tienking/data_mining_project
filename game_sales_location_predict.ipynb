# %%
import pandas as pd
import numpy as np
from sklearn import tree
import graphviz
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import BernoulliNB

# %%
# load dataset from csv file
df = pd.read_csv("datasets/Video_Game_Sales_as_of_Jan_2017.csv", index_col="Name")
df.head()
# Out:
#                          Platform  Year_of_Release         Genre Publisher  \
# Name
# Wii Sports                    Wii           2006.0        Sports  Nintendo
# Super Mario Bros.             NES           1985.0      Platform  Nintendo
# Mario Kart Wii                Wii           2008.0        Racing  Nintendo
# Wii Sports Resort             Wii           2009.0        Sports  Nintendo
# Pokemon Red/Pokemon Blue        G           1996.0  Role-Playing  Nintendo
#
#                           NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii Sports                   41.36     28.96      3.77         8.45
# Super Mario Bros.            29.08      3.58      6.81         0.77
# Mario Kart Wii               15.68     12.80      3.79         3.29
# Wii Sports Resort            15.61     10.95      3.28         2.95
# Pokemon Red/Pokemon Blue     11.27      8.89     10.22         1.00
#
#                           Global_Sales  Critic_Score  Critic_Count  \
# Name
# Wii Sports                       82.54          76.0          51.0
# Super Mario Bros.                40.24           NaN           NaN
# Mario Kart Wii                   35.57          82.0          73.0
# Wii Sports Resort                32.78          80.0          73.0
# Pokemon Red/Pokemon Blue         31.37           NaN           NaN
#
#                           User_Score  User_Count Rating
# Name
# Wii Sports                       8.0       324.0      E
# Super Mario Bros.                NaN         NaN    NaN
# Mario Kart Wii                   8.3       712.0      E
# Wii Sports Resort                8.0       193.0      E
# Pokemon Red/Pokemon Blue         NaN         NaN    NaN

# %%
# drop columns that is useless
df.drop(columns=['Critic_Score', 'Critic_Count', 'User_Score', 'User_Count', 'Global_Sales', 'Year_of_Release'], inplace=True)
df.head()
# Out:
#                          Platform         Genre Publisher  NA_Sales  EU_Sales  \
# Name
# Wii Sports                    Wii        Sports  Nintendo     41.36     28.96
# Super Mario Bros.             NES      Platform  Nintendo     29.08      3.58
# Mario Kart Wii                Wii        Racing  Nintendo     15.68     12.80
# Wii Sports Resort             Wii        Sports  Nintendo     15.61     10.95
# Pokemon Red/Pokemon Blue        G  Role-Playing  Nintendo     11.27      8.89
#
#                           JP_Sales  Other_Sales Rating
# Name
# Wii Sports                    3.77         8.45      E
# Super Mario Bros.             6.81         0.77    NaN
# Mario Kart Wii                3.79         3.29      E
# Wii Sports Resort             3.28         2.95      E
# Pokemon Red/Pokemon Blue     10.22         1.00    NaN

# %%
# create label from 4 columns in dataset and drop them
label = df[['NA_Sales' ,'EU_Sales', 'JP_Sales', 'Other_Sales']].idxmax(axis=1)
df.drop(columns=['NA_Sales' ,'EU_Sales', 'JP_Sales', 'Other_Sales'], inplace=True)
df.head()
# Out:
#                          Platform         Genre Publisher Rating
# Name
# Wii Sports                    Wii        Sports  Nintendo      E
# Super Mario Bros.             NES      Platform  Nintendo    NaN
# Mario Kart Wii                Wii        Racing  Nintendo      E
# Wii Sports Resort             Wii        Sports  Nintendo      E
# Pokemon Red/Pokemon Blue        G  Role-Playing  Nintendo    NaN

# %%
# use One Hot Encoding to create binary columns
num_df = pd.get_dummies(df, dtype='float64', dummy_na=True, drop_first=True, columns=list(df))
num_df.head()
# Out:
#                           Platform_3DO  Platform_3DS  Platform_DC  \
# Name
# Wii Sports                         0.0           0.0          0.0
# Super Mario Bros.                  0.0           0.0          0.0
# Mario Kart Wii                     0.0           0.0          0.0
# Wii Sports Resort                  0.0           0.0          0.0
# Pokemon Red/Pokemon Blue           0.0           0.0          0.0
#
#                           Platform_DS  Platform_G  Platform_GBA  Platform_GC  \
# Name
# Wii Sports                        0.0         0.0           0.0          0.0
# Super Mario Bros.                 0.0         0.0           0.0          0.0
# Mario Kart Wii                    0.0         0.0           0.0          0.0
# Wii Sports Resort                 0.0         0.0           0.0          0.0
# Pokemon Red/Pokemon Blue          0.0         1.0           0.0          0.0
#
#                           Platform_GEN  Platform_GG  Platform_N64     ...      \
# Name                                                                  ...
# Wii Sports                         0.0          0.0           0.0     ...
# Super Mario Bros.                  0.0          0.0           0.0     ...
# Mario Kart Wii                     0.0          0.0           0.0     ...
# Wii Sports Resort                  0.0          0.0           0.0     ...
# Pokemon Red/Pokemon Blue           0.0          0.0           0.0     ...
#
#                           Publisher_responDESIGN  Publisher_nan  Rating_E  \
# Name
# Wii Sports                                   0.0            0.0       1.0
# Super Mario Bros.                            0.0            0.0       0.0
# Mario Kart Wii                               0.0            0.0       1.0
# Wii Sports Resort                            0.0            0.0       1.0
# Pokemon Red/Pokemon Blue                     0.0            0.0       0.0
#
#                           Rating_E10+  Rating_EC  Rating_K-A  Rating_M  \
# Name
# Wii Sports                        0.0        0.0         0.0       0.0
# Super Mario Bros.                 0.0        0.0         0.0       0.0
# Mario Kart Wii                    0.0        0.0         0.0       0.0
# Wii Sports Resort                 0.0        0.0         0.0       0.0
# Pokemon Red/Pokemon Blue          0.0        0.0         0.0       0.0
#
#                           Rating_RP  Rating_T  Rating_nan
# Name
# Wii Sports                      0.0       0.0         0.0
# Super Mario Bros.               0.0       0.0         1.0
# Mario Kart Wii                  0.0       0.0         0.0
# Wii Sports Resort               0.0       0.0         0.0
# Pokemon Red/Pokemon Blue        0.0       0.0         1.0
#
# [5 rows x 678 columns]

# %%
# split train test set from data input and label
X_train, X_test, y_train, y_test = train_test_split(num_df, label, shuffle=True, test_size=0.33, random_state=47)

# %%
# create decision tree object
dt_clf = tree.DecisionTreeClassifier()
dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# use model to predict on test set and calculate accuracy
y_pred = dt_clf.predict(X_test)
print("Accuracy: {0}".format(accuracy_score(y_test, y_pred)))
# Out:
# Accuracy: 0.8041057759220599

# %%
# create a view of decision tree and store it
dot_data = tree.export_graphviz(dt_clf,
                                feature_names=list(num_df), 
                                class_names=['NA_Sales','EU_Sales','JP_Sales','Other_Sales'], 
                                filled=True, 
                                rounded=True, 
                                special_characters=True)

# %%
# test Bernoulli Naive Bayes model
nb_clf = BernoulliNB()
nb_clf.fit(X_train, y_train)
y_pred = nb_clf.predict(X_test)
print("Accuracy: {0}".format(accuracy_score(y_test, y_pred)))
# Out:
# Accuracy: 0.8126304801670147
